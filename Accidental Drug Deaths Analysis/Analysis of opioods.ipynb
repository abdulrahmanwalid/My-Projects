# %% [markdown]
# #  Unraveling the Opioid Crisis: A Comprehensive Analysis of Overdose Trends, Risk Factors, and Opportunities for Intervention (2012-2021)"

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Data Pre-proceesing

# %%
df=pd.read_csv('Accidental_Drug_Related_Deaths_2012-2021.csv')
df.head()
# Out:
#          Date      Date Type   Age     Sex   Race Description of Injury  \
# 0   5/29/2012  Date of death  37.0    Male  Black          Used Cocaine
# 1   6/27/2012  Date of death  37.0    Male  White              Drug Use
# 2   3/24/2014  Date of death  28.0    Male  White              Drug Use
# 3  12/31/2014  Date of death  26.0  Female  White                   NaN
# 4   1/16/2016  Date of death  41.0    Male  White              Drug Use
#
#     Death City Death County Death State               Cause of Death  ...  \
# 0          NaN          NaN         NaN             Cocaine Toxicity  ...
# 1      NORWICH   NEW LONDON         NaN              Heroin Toxicity  ...
# 2  MARLBOROUGH          NaN         NaN          Heroin Intoxication  ...
# 3       BALTIC   NEW LONDON         NaN    Acute Heroin Intoxication  ...
# 4   BRIDGEPORT          NaN         NaN  Acute Fentanyl Intoxication  ...
#
#   Tramad Hydromorphone Morphine (Not Heroin) Xylazine Gabapentin Opiate NOS  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9202 entries, 0 to 9201
# Data columns (total 35 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Date                           9202 non-null   object
#  1   Date Type                      9202 non-null   object
#  2   Age                            9200 non-null   float64
#  3   Sex                            9194 non-null   object
#  4   Race                           9178 non-null   object
#  5   Description of Injury          8411 non-null   object
#  6   Death City                     9197 non-null   object
#  7   Death County                   8090 non-null   object
#  8   Death State                    6873 non-null   object
#  9   Cause of Death                 9202 non-null   object
#  10  Manner of Death                9193 non-null   object
#  11  Other Significant Conditions   815 non-null    object
# ...

# %%
df.isna().sum()
# Out:
# Date                                0
# Date Type                           0
# Age                                 2
# Sex                                 8
# Race                               24
# Description of Injury             791
# Death City                          5
# Death County                     1112
# Death State                      2329
# Cause of Death                      0
# Manner of Death                     9
# Other Significant Conditions     8387
# Heroin                           5855
# Heroin death certificate (DC)    8462
# Cocaine                          6031
# Fentanyl                         3530
# Fentanyl Analogue                8474
# Oxycodone                        8325
# Oxymorphone                      9054
# Ethanol                          6732
# Hydrocodone                      9047
# Benzodiazepine                   6964
# Methadone                        8388
# Meth/Amphetamine                 9075
# Amphet                           8917
# ...

# %%
columns_to_modify = [
    "Heroin", "Heroin death certificate (DC)", "Cocaine", "Fentanyl", "Fentanyl Analogue", "Oxycodone",
    "Oxymorphone", "Ethanol", "Hydrocodone", "Benzodiazepine", "Methadone", "Meth/Amphetamine",
    "Amphet", "Tramad", "Hydromorphone", "Morphine (Not Heroin)", "Xylazine", "Gabapentin",
    "Opiate NOS", "Heroin/Morph/Codeine", "Other Opioid", "Any Opioid","Other"
]

for col in columns_to_modify:
    df[col] = df[col].apply(lambda x: "Present" if x == "Y" else "Non-Present")
    
df.isna().sum()
# Out:
# Date                                0
# Date Type                           0
# Age                                 2
# Sex                                 8
# Race                               24
# Description of Injury             791
# Death City                          5
# Death County                     1112
# Death State                      2329
# Cause of Death                      0
# Manner of Death                     9
# Other Significant Conditions     8387
# Heroin                              0
# Heroin death certificate (DC)       0
# Cocaine                             0
# Fentanyl                            0
# Fentanyl Analogue                   0
# Oxycodone                           0
# Oxymorphone                         0
# Ethanol                             0
# Hydrocodone                         0
# Benzodiazepine                      0
# Methadone                           0
# Meth/Amphetamine                    0
# Amphet                              0
# ...

# %%
df['Description of Injury'].replace(np.nan, 'Unknown', inplace=True)
df.isna().sum()
# Out:
# Date                                0
# Date Type                           0
# Age                                 2
# Sex                                 8
# Race                               24
# Description of Injury               0
# Death City                          5
# Death County                     1112
# Death State                      2329
# Cause of Death                      0
# Manner of Death                     9
# Other Significant Conditions     8387
# Heroin                              0
# Heroin death certificate (DC)       0
# Cocaine                             0
# Fentanyl                            0
# Fentanyl Analogue                   0
# Oxycodone                           0
# Oxymorphone                         0
# Ethanol                             0
# Hydrocodone                         0
# Benzodiazepine                      0
# Methadone                           0
# Meth/Amphetamine                    0
# Amphet                              0
# ...

# %%
#Dropping unneccessary columns

columns_to_drop=['Death City','Death County','Death State','Other Significant Conditions']
df.drop(columns_to_drop, axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 4
#       1 #Dropping unneccessary columns
#       3 columns_to_drop=['Death City','Death County','Death State','Other Significant Conditions']
# ----> 4 df.drop(columns_to_drop, axis=1, inplace=True)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.isna().sum()
